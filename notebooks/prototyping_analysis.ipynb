# %%
import pandas as pd

# %%
df = pd.read_csv('../data/car_database.csv', sep=';')

# %%
display(df)
# Out:
#               car                                          version  engine  \
# 0  Fiat Argo 2026                    1.0 FIREFLY FLEX DRIVE MANUAL     1.0
# 1  Fiat Argo 2026   1.0 FIREFLY FLEX DRIVE MANUAL + PACK DRIVE TOP     1.0
# 2  Fiat Argo 2026                 1.3 FIREFLY FLEX TREKKING MANUAL     1.3
# 3  Fiat Argo 2026  1.3 FIREFLY FLEX TREKKING MANUAL + Trekking TOP     1.3
# 4  Fiat Argo 2026                       1.3 FIREFLY FLEX DRIVE CVT     1.3
# 5  Fiat Argo 2026     1.3 FIREFLY FLEX DRIVE CVT + PACK S-DESIGN       1.3
# 6  Fiat Argo 2026                    1.3 FIREFLY FLEX TREKKING CVT     1.3
# 7  Fiat Argo 2026     1.3 FIREFLY FLEX TREKKING CVT + Trekking TOP     1.3
#
#   transmission  horsepower  torque  city_fuel_economy  highway_fuel_economy  \
# 0       manual          72    10.4               13.6                  14.5
# 1       manual          72    10.4               13.6                  14.5
# ...
